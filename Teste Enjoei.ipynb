# %% [markdown]
# #### Documentação da API: https://fakestoreapi.com/docs

# %% [markdown]
# #### Importação de bibliotecas úteis ao longo do código

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# #### Definição de variáveis e coleta de dados da API

# %%
headers = {
    "Content-Type": "application/json",
    "Accept": "application/json"
}

# %% [markdown]
# #### Dados de Usuários

# %%
url_users = "https://fakestoreapi.com/users?sort=asc"

response = requests.get(url_users, headers=headers)

if response.status_code == 200:
    users = response.json() 

else:
    print(f"Error: {response.status_code} - {response.text}")

# %% [markdown]
# #### Produtos da loja

# %%
url_products = "https://fakestoreapi.com/products?sort=asc"

response = requests.get(url_products, headers=headers)

if response.status_code == 200:
    products = response.json() 

else:
    print(f"Error: {response.status_code} - {response.text}")

# %% [markdown]
# #### Carrinho de compras

# %%
url_cart = "https://fakestoreapi.com/carts?sort=asc"

response = requests.get(url_cart, headers=headers)

if response.status_code == 200:
    cart = response.json() 

else:
    print(f"Error: {response.status_code} - {response.text}")

# %% [markdown]
# ##### Transformações dos dados de usuários

# %%
users_df = pd.DataFrame(users)

users_df
# Out:
#                                              address  id               email  \
# 0  {'geolocation': {'lat': '-37.3159', 'long': '8...   1      john@gmail.com
# 1  {'geolocation': {'lat': '-37.3159', 'long': '8...   2  morrison@gmail.com
# 2  {'geolocation': {'lat': '40.3467', 'long': '-3...   3     kevin@gmail.com
# 3  {'geolocation': {'lat': '50.3467', 'long': '-2...   4       don@gmail.com
# 4  {'geolocation': {'lat': '40.3467', 'long': '-4...   5     derek@gmail.com
# 5  {'geolocation': {'lat': '20.1677', 'long': '-1...   6   david_r@gmail.com
# 6  {'geolocation': {'lat': '10.3456', 'long': '20...   7    miriam@gmail.com
# 7  {'geolocation': {'lat': '50.3456', 'long': '10...   8   william@gmail.com
# 8  {'geolocation': {'lat': '40.12456', 'long': '2...   9      kate@gmail.com
# 9  {'geolocation': {'lat': '30.24788', 'long': '-...  10    jimmie@gmail.com
#
#     username      password                                             name  \
# 0      johnd       m38rmF$         {'firstname': 'john', 'lastname': 'doe'}
# 1   mor_2314        83r5^_   {'firstname': 'david', 'lastname': 'morrison'}
# 2  kevinryan     kev02937@       {'firstname': 'kevin', 'lastname': 'ryan'}
# 3     donero        ewedon        {'firstname': 'don', 'lastname': 'romer'}
# 4      derek      jklg*_56     {'firstname': 'derek', 'lastname': 'powell'}
# 5    david_r      3478*#54    {'firstname': 'david', 'lastname': 'russell'}
# 6     snyder      f238&@*$    {'firstname': 'miriam', 'lastname': 'snyder'}
# 7    hopkins  William56$hj  {'firstname': 'william', 'lastname': 'hopkins'}
# 8     kate_h      kfejk@*_        {'firstname': 'kate', 'lastname': 'hale'}
# 9   jimmie_k     klein*#%*     {'firstname': 'jimmie', 'lastname': 'klein'}
#
#             phone  __v
# 0  1-570-236-7033    0
# 1  1-570-236-7033    0
# 2  1-567-094-1345    0
# 3  1-765-789-6734    0
# 4  1-956-001-1945    0
# 5  1-678-345-9856    0
# 6  1-123-943-0563    0
# 7  1-478-001-0890    0
# 8  1-678-456-1934    0
# 9  1-104-001-4567    0

# %% [markdown]
# ##### Remoção de colunas sem uso

# %%
users_df.drop(columns=['__v'], inplace=True)

# %% [markdown]
# ##### Renomeando colunas

# %%
users_df.rename(columns={'id': 'userId'}, inplace=True)

# %% [markdown]
# ##### Normalizando o endereço do usuário

# %%
users_df['address_latitude'] = users_df['address'].apply(lambda x: x['geolocation']['lat'])

users_df['address_longitude'] = users_df['address'].apply(lambda x: x['geolocation']['long'])

users_df.drop(columns=['address'], inplace=True)

users_df
# Out:
#    userId               email   username      password  \
# 0       1      john@gmail.com      johnd       m38rmF$
# 1       2  morrison@gmail.com   mor_2314        83r5^_
# 2       3     kevin@gmail.com  kevinryan     kev02937@
# 3       4       don@gmail.com     donero        ewedon
# 4       5     derek@gmail.com      derek      jklg*_56
# 5       6   david_r@gmail.com    david_r      3478*#54
# 6       7    miriam@gmail.com     snyder      f238&@*$
# 7       8   william@gmail.com    hopkins  William56$hj
# 8       9      kate@gmail.com     kate_h      kfejk@*_
# 9      10    jimmie@gmail.com   jimmie_k     klein*#%*
#
#                                               name           phone  \
# 0         {'firstname': 'john', 'lastname': 'doe'}  1-570-236-7033
# 1   {'firstname': 'david', 'lastname': 'morrison'}  1-570-236-7033
# 2       {'firstname': 'kevin', 'lastname': 'ryan'}  1-567-094-1345
# 3        {'firstname': 'don', 'lastname': 'romer'}  1-765-789-6734
# 4     {'firstname': 'derek', 'lastname': 'powell'}  1-956-001-1945
# 5    {'firstname': 'david', 'lastname': 'russell'}  1-678-345-9856
# 6    {'firstname': 'miriam', 'lastname': 'snyder'}  1-123-943-0563
# 7  {'firstname': 'william', 'lastname': 'hopkins'}  1-478-001-0890
# 8        {'firstname': 'kate', 'lastname': 'hale'}  1-678-456-1934
# 9     {'firstname': 'jimmie', 'lastname': 'klein'}  1-104-001-4567
#
#   address_latitude address_longitude
# 0         -37.3159           81.1496
# 1         -37.3159           81.1496
# 2          40.3467          -30.1310
# 3          50.3467          -20.1310
# 4          40.3467          -40.1310
# 5          20.1677          -10.6789
# 6          10.3456           20.6419
# 7          50.3456           10.6419
# 8         40.12456           20.5419
# 9         30.24788        -20.545419

# %% [markdown]
# ##### Normalizando o nome do usuário

# %%
users_df['user_firstname'] = users_df['name'].apply(lambda x: x['firstname'])

users_df['user_lastname'] = users_df['name'].apply(lambda x: x['lastname'])

users_df.drop(columns=['name'], inplace=True)

users_df
# Out:
#    userId               email   username      password           phone  \
# 0       1      john@gmail.com      johnd       m38rmF$  1-570-236-7033
# 1       2  morrison@gmail.com   mor_2314        83r5^_  1-570-236-7033
# 2       3     kevin@gmail.com  kevinryan     kev02937@  1-567-094-1345
# 3       4       don@gmail.com     donero        ewedon  1-765-789-6734
# 4       5     derek@gmail.com      derek      jklg*_56  1-956-001-1945
# 5       6   david_r@gmail.com    david_r      3478*#54  1-678-345-9856
# 6       7    miriam@gmail.com     snyder      f238&@*$  1-123-943-0563
# 7       8   william@gmail.com    hopkins  William56$hj  1-478-001-0890
# 8       9      kate@gmail.com     kate_h      kfejk@*_  1-678-456-1934
# 9      10    jimmie@gmail.com   jimmie_k     klein*#%*  1-104-001-4567
#
#   address_latitude address_longitude user_firstname user_lastname
# 0         -37.3159           81.1496           john           doe
# 1         -37.3159           81.1496          david      morrison
# 2          40.3467          -30.1310          kevin          ryan
# 3          50.3467          -20.1310            don         romer
# 4          40.3467          -40.1310          derek        powell
# 5          20.1677          -10.6789          david       russell
# 6          10.3456           20.6419         miriam        snyder
# 7          50.3456           10.6419        william       hopkins
# 8         40.12456           20.5419           kate          hale
# 9         30.24788        -20.545419         jimmie         klein

# %% [markdown]
# ##### Transformações dos dados de produtos

# %%
products_df = pd.DataFrame(products)

products_df.head(5)
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
# 3   4                               Mens Casual Slim Fit   15.99
# 4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
#
#                                          description        category  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing
# 1  Slim-fitting style, contrast raglan long sleev...  men's clothing
# 2  great outerwear jackets for Spring/Autumn/Wint...  men's clothing
# 3  The color could be slightly different between ...  men's clothing
# 4  From our Legends Collection, the Naga was insp...        jewelery
#
#                                                image  \
# 0  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...
# 1  https://fakestoreapi.com/img/71-3HjGNDUL._AC_S...
# 2  https://fakestoreapi.com/img/71li-ujtlUL._AC_U...
# 3  https://fakestoreapi.com/img/71YXzeOuslL._AC_U...
# 4  https://fakestoreapi.com/img/71pWzhdJNwL._AC_U...
#
#                         rating
# 0  {'rate': 3.9, 'count': 120}
# 1  {'rate': 4.1, 'count': 259}
# 2  {'rate': 4.7, 'count': 500}
# 3  {'rate': 2.1, 'count': 430}
# 4  {'rate': 4.6, 'count': 400}

# %% [markdown]
# ##### Renomeando colunas

# %%
products_df.rename(columns={'id': 'product_id'}, inplace=True)

# %% [markdown]
# ##### Normalizando a avaliação do produto

# %%
products_df['product_rate'] = products_df['rating'].apply(lambda x: x['rate'])

products_df['number_of_reviews'] = products_df['rating'].apply(lambda x: x['count'])

products_df.drop(columns=['rating'], inplace=True)

products_df.head(5)
# Out:
#    product_id                                              title   price  \
# 0           1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1           2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2           3                                 Mens Cotton Jacket   55.99
# 3           4                               Mens Casual Slim Fit   15.99
# 4           5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
#
#                                          description        category  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing
# 1  Slim-fitting style, contrast raglan long sleev...  men's clothing
# 2  great outerwear jackets for Spring/Autumn/Wint...  men's clothing
# 3  The color could be slightly different between ...  men's clothing
# 4  From our Legends Collection, the Naga was insp...        jewelery
#
#                                                image  product_rate  \
# 0  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...           3.9
# 1  https://fakestoreapi.com/img/71-3HjGNDUL._AC_S...           4.1
# 2  https://fakestoreapi.com/img/71li-ujtlUL._AC_U...           4.7
# 3  https://fakestoreapi.com/img/71YXzeOuslL._AC_U...           2.1
# 4  https://fakestoreapi.com/img/71pWzhdJNwL._AC_U...           4.6
#
#    number_of_reviews
# 0                120
# 1                259
# 2                500
# 3                430
# 4                400

# %% [markdown]
# ##### Transformações dos dados de carrinho de compras

# %%
cart_df = pd.DataFrame(cart)

cart_df
# Out:
#    id  userId                      date  \
# 0   1       1  2020-03-02T00:00:00.000Z
# 1   2       1  2020-01-02T00:00:00.000Z
# 2   3       2  2020-03-01T00:00:00.000Z
# 3   4       3  2020-01-01T00:00:00.000Z
# 4   5       3  2020-03-01T00:00:00.000Z
# 5   6       4  2020-03-01T00:00:00.000Z
# 6   7       8  2020-03-01T00:00:00.000Z
#
#                                             products  __v
# 0  [{'productId': 1, 'quantity': 4}, {'productId'...    0
# 1  [{'productId': 2, 'quantity': 4}, {'productId'...    0
# 2  [{'productId': 1, 'quantity': 2}, {'productId'...    0
# 3                  [{'productId': 1, 'quantity': 4}]    0
# 4  [{'productId': 7, 'quantity': 1}, {'productId'...    0
# 5  [{'productId': 10, 'quantity': 2}, {'productId...    0
# 6                 [{'productId': 18, 'quantity': 1}]    0

# %% [markdown]
# ##### Remoção de colunas sem uso

# %%
cart_df.drop(columns=['__v'], inplace=True)

# %% [markdown]
# ##### Explodindo o dataframe de acordo com a coluna de produtos comprados

# %%
exploded_cart_df = cart_df.explode('products')

exploded_cart_df['product_id'] = exploded_cart_df['products'].apply(lambda x: x['productId'])

exploded_cart_df['quantity'] = exploded_cart_df['products'].apply(lambda x: x['quantity'])

exploded_cart_df.drop(columns=['products'], inplace=True)

exploded_cart_df
# Out:
#    id  userId                      date  product_id  quantity
# 0   1       1  2020-03-02T00:00:00.000Z           1         4
# 0   1       1  2020-03-02T00:00:00.000Z           2         1
# 0   1       1  2020-03-02T00:00:00.000Z           3         6
# 1   2       1  2020-01-02T00:00:00.000Z           2         4
# 1   2       1  2020-01-02T00:00:00.000Z           1        10
# 1   2       1  2020-01-02T00:00:00.000Z           5         2
# 2   3       2  2020-03-01T00:00:00.000Z           1         2
# 2   3       2  2020-03-01T00:00:00.000Z           9         1
# 3   4       3  2020-01-01T00:00:00.000Z           1         4
# 4   5       3  2020-03-01T00:00:00.000Z           7         1
# 4   5       3  2020-03-01T00:00:00.000Z           8         1
# 5   6       4  2020-03-01T00:00:00.000Z          10         2
# 5   6       4  2020-03-01T00:00:00.000Z          12         3
# 6   7       8  2020-03-01T00:00:00.000Z          18         1

# %% [markdown]
# #### Aplicação de regras de teste

# %% [raw]
# Este arquivo deve conter as seguintes informações:
#
#   - identificador de usuário
#
#   - data mais recente em que o usuário adicionou produtos ao carrinho
#
#   - categoria em que o usuário tem mais produtos adicionados ao carrinho

# %% [markdown]
# #### JOIN entre as tabelas de carrinho de compras com produtos

# %%
products_in_cart = pd.merge(
    exploded_cart_df, 
    products_df, 
    on='product_id',
    how='inner'
)[[
    'userId', 
    'date',
    'quantity',
    'category'
]]

products_in_cart
# Out:
#     userId                      date  quantity          category
# 0        1  2020-03-02T00:00:00.000Z         4    men's clothing
# 1        1  2020-01-02T00:00:00.000Z        10    men's clothing
# 2        2  2020-03-01T00:00:00.000Z         2    men's clothing
# 3        3  2020-01-01T00:00:00.000Z         4    men's clothing
# 4        1  2020-03-02T00:00:00.000Z         1    men's clothing
# 5        1  2020-01-02T00:00:00.000Z         4    men's clothing
# 6        1  2020-03-02T00:00:00.000Z         6    men's clothing
# 7        1  2020-01-02T00:00:00.000Z         2          jewelery
# 8        2  2020-03-01T00:00:00.000Z         1       electronics
# 9        3  2020-03-01T00:00:00.000Z         1          jewelery
# 10       3  2020-03-01T00:00:00.000Z         1          jewelery
# 11       4  2020-03-01T00:00:00.000Z         2       electronics
# 12       4  2020-03-01T00:00:00.000Z         3       electronics
# 13       8  2020-03-01T00:00:00.000Z         1  women's clothing

# %% [markdown]
# #### Obtendo a data mais recente em que cada usuário comprou algo

# %%
recent_purchases = (
    products_in_cart[['userId',	'date']]
    .loc[products_in_cart.groupby('userId')['date'].idxmax()]
)

recent_purchases
# Out:
#     userId                      date
# 0        1  2020-03-02T00:00:00.000Z
# 2        2  2020-03-01T00:00:00.000Z
# 9        3  2020-03-01T00:00:00.000Z
# 11       4  2020-03-01T00:00:00.000Z
# 13       8  2020-03-01T00:00:00.000Z

# %% [markdown]
# #### Obtendo a categoria em que o usuário mais fez compras

# %%
category_count = (
    products_in_cart[['userId',	'category', 'quantity']]
    .groupby(['userId', 'category'])['quantity'].sum().reset_index()
)

category_count
# Out:
#    userId          category  quantity
# 0       1          jewelery         2
# 1       1    men's clothing        25
# 2       2       electronics         1
# 3       2    men's clothing         2
# 4       3          jewelery         2
# 5       3    men's clothing         4
# 6       4       electronics         5
# 7       8  women's clothing         1

# %%
prefered_category = category_count.loc[category_count.groupby(['userId'])['quantity'].idxmax()]

prefered_category
# Out:
#    userId          category  quantity
# 1       1    men's clothing        25
# 3       2    men's clothing         2
# 5       3    men's clothing         4
# 6       4       electronics         5
# 7       8  women's clothing         1

# %% [markdown]
# #### JOIN entre as tabelas resultantes

# %%
final_product_df = pd.merge(
    prefered_category, 
    recent_purchases, 
    on='userId',
    how='inner'
)[[
    'userId', 
    'category',
    'date'
]]

final_product_df.rename(columns={'category': 'prefered_category'}, inplace=True)

final_product_df.rename(columns={'date': 'most_recent_date'}, inplace=True)

final_product_df
# Out:
#    userId prefered_category          most_recent_date
# 0       1    men's clothing  2020-03-02T00:00:00.000Z
# 1       2    men's clothing  2020-03-01T00:00:00.000Z
# 2       3    men's clothing  2020-03-01T00:00:00.000Z
# 3       4       electronics  2020-03-01T00:00:00.000Z
# 4       8  women's clothing  2020-03-01T00:00:00.000Z

# %% [markdown]
# #### JOIN com a tabela de usuários para obtenção do identificador de cada um deles

# %%
products_with_users_id = pd.merge(
    final_product_df, 
    users_df, 
    on='userId',
    how='inner'
)

products_with_users_id
# Out:
#    userId prefered_category          most_recent_date               email  \
# 0       1    men's clothing  2020-03-02T00:00:00.000Z      john@gmail.com
# 1       2    men's clothing  2020-03-01T00:00:00.000Z  morrison@gmail.com
# 2       3    men's clothing  2020-03-01T00:00:00.000Z     kevin@gmail.com
# 3       4       electronics  2020-03-01T00:00:00.000Z       don@gmail.com
# 4       8  women's clothing  2020-03-01T00:00:00.000Z   william@gmail.com
#
#     username      password           phone address_latitude address_longitude  \
# 0      johnd       m38rmF$  1-570-236-7033         -37.3159           81.1496
# 1   mor_2314        83r5^_  1-570-236-7033         -37.3159           81.1496
# 2  kevinryan     kev02937@  1-567-094-1345          40.3467          -30.1310
# 3     donero        ewedon  1-765-789-6734          50.3467          -20.1310
# 4    hopkins  William56$hj  1-478-001-0890          50.3456           10.6419
#
#   user_firstname user_lastname
# 0           john           doe
# 1          david      morrison
# 2          kevin          ryan
# 3            don         romer
# 4        william       hopkins

# %% [markdown]
# #### Exportação do resultado em arquivo JSON

# %%
products_with_users_id.to_json('teste_enjoei_rodrigo_amandio.json', orient='records', lines=True)
